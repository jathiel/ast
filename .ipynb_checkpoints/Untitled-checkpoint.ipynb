# %%
from src.models import ASTModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.models import ASTModel
#
# File ~\OneDrive\Documents\GitHub\ast\src\models\__init__.py:8
#       1 # -*- coding: utf-8 -*-
#       2 # @Time    : 6/19/21 4:31 PM
#       3 # @Author  : Yuan Gong
#       4 # @Affiliation  : Massachusetts Institute of Technology
#       5 # @Email   : yuangong@mit.edu
#       6 # @File    : __init__.py
# ----> 8 from .ast_models import *
#
# File ~\OneDrive\Documents\GitHub\ast\src\models\ast_models.py:14
#      12 import wget
#      13 os.environ['TORCH_HOME'] = '../../pretrained_models'
# ---> 14 import timm
#      15 from timm.models.layers import to_2tuple,trunc_normal_
#      17 # override the timm package to relax the input shape constraint.
#
# File ~\anaconda3\Lib\site-packages\timm\__init__.py:2
#       1 from .version import __version__
# ----> 2 from .models import create_model, list_models, is_model, list_modules, model_entrypoint, \
#       3     is_scriptable, is_exportable, set_scriptable, set_exportable
#
# File ~\anaconda3\Lib\site-packages\timm\models\__init__.py:1
# ----> 1 from .byobnet import *
#       2 from .cspnet import *
#       3 from .densenet import *
#
# File ~\anaconda3\Lib\site-packages\timm\models\byobnet.py:36
#      33 import torch
#      34 import torch.nn as nn
# ---> 36 from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
#      37 from .helpers import build_model_with_cfg
#      38 from .layers import ClassifierHead, ConvBnAct, DropPath, AvgPool2dSame, \
#      39     create_conv2d, get_act_layer, get_attn, convert_norm_act, make_divisible
#
# File ~\anaconda3\Lib\site-packages\timm\data\__init__.py:7
#       5 from .dataset import ImageDataset, IterableImageDataset, AugMixDataset
#       6 from .dataset_factory import create_dataset
# ----> 7 from .loader import create_loader
#       8 from .mixup import Mixup, FastCollateMixup
#       9 from .parsers import create_parser
#
# File ~\anaconda3\Lib\site-packages\timm\data\loader.py:12
#       9 import torch.utils.data
#      10 import numpy as np
# ---> 12 from .transforms_factory import create_transform
#      13 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
#      14 from .distributed_sampler import OrderedDistributedSampler
#
# File ~\anaconda3\Lib\site-packages\timm\data\transforms_factory.py:9
#       6 import math
#       8 import torch
# ----> 9 from torchvision import transforms
#      11 from timm.data.constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, DEFAULT_CROP_PCT
#      12 from timm.data.auto_augment import rand_augment_transform, augment_and_mix_transform, auto_augment_transform
#
# File ~\anaconda3\Lib\site-packages\torchvision\__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~\anaconda3\Lib\site-packages\torchvision\datasets\__init__.py:1
# ----> 1 from ._optical_flow import FlyingChairs, FlyingThings3D, HD1K, KittiFlow, Sintel
#       2 from ._stereo_matching import (
#       3     CarlaStereo,
#       4     CREStereo,
#    (...)
#      12     SintelStereo,
#      13 )
#      14 from .caltech import Caltech101, Caltech256
#
# File ~\anaconda3\Lib\site-packages\torchvision\datasets\_optical_flow.py:12
#       9 import torch
#      10 from PIL import Image
# ---> 12 from ..io.image import _read_png_16
#      13 from .utils import _read_pfm, verify_str_arg
#      14 from .vision import VisionDataset
#
# File ~\anaconda3\Lib\site-packages\torchvision\io\__init__.py:5
#       1 from typing import Any, Dict, Iterator
#       3 import torch
# ----> 5 from ..utils import _log_api_usage_once
#       7 try:
#       8     from ._load_gpu_decoder import _HAS_GPU_VIDEO_DECODER
#
# File ~\anaconda3\Lib\site-packages\torchvision\utils.py:11
#       9 import numpy as np
#      10 import torch
# ---> 11 from PIL import Image, ImageColor, ImageDraw, ImageFont
#      13 __all__ = [
#      14     "make_grid",
#      15     "save_image",
#    (...)
#      19     "flow_to_image",
#      20 ]
#      23 @torch.no_grad()
#      24 def make_grid(
#      25     tensor: Union[torch.Tensor, List[torch.Tensor]],
#    (...)
#      31     pad_value: float = 0.0,
#      32 ) -> torch.Tensor:
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageDraw.py:40
#      37 from typing import Sequence, cast
#      39 from . import Image, ImageColor
# ---> 40 from ._typing import Coords
#      42 """
#      43 A simple 2D drawing interface for PIL images.
#      44 <p>
#      45 Application code should use the <b>Draw</b> factory, instead of
#      46 directly.
#      47 """
#      50 class ImageDraw:
#
# ImportError: cannot import name 'Coords' from 'PIL._typing' (C:\Users\blind\anaconda3\Lib\site-packages\PIL\_typing.py)

# %%
ASTModel(label_dim=527, \
         fstride=10, tstride=10, \
         input_fdim=128, input_tdim=1024, \
         imagenet_pretrain=True, audioset_pretrain=False, \
         model_size='base384')

# %%
import timm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import timm
#
# File ~\anaconda3\Lib\site-packages\timm\__init__.py:2
#       1 from .version import __version__
# ----> 2 from .models import create_model, list_models, is_model, list_modules, model_entrypoint, \
#       3     is_scriptable, is_exportable, set_scriptable, set_exportable
#
# File ~\anaconda3\Lib\site-packages\timm\models\__init__.py:1
# ----> 1 from .byobnet import *
#       2 from .cspnet import *
#       3 from .densenet import *
#
# File ~\anaconda3\Lib\site-packages\timm\models\byobnet.py:36
#      33 import torch
#      34 import torch.nn as nn
# ---> 36 from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
#      37 from .helpers import build_model_with_cfg
#      38 from .layers import ClassifierHead, ConvBnAct, DropPath, AvgPool2dSame, \
#      39     create_conv2d, get_act_layer, get_attn, convert_norm_act, make_divisible
#
# File ~\anaconda3\Lib\site-packages\timm\data\__init__.py:7
#       5 from .dataset import ImageDataset, IterableImageDataset, AugMixDataset
#       6 from .dataset_factory import create_dataset
# ----> 7 from .loader import create_loader
#       8 from .mixup import Mixup, FastCollateMixup
#       9 from .parsers import create_parser
#
# File ~\anaconda3\Lib\site-packages\timm\data\loader.py:12
#       9 import torch.utils.data
#      10 import numpy as np
# ---> 12 from .transforms_factory import create_transform
#      13 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
#      14 from .distributed_sampler import OrderedDistributedSampler
#
# File ~\anaconda3\Lib\site-packages\timm\data\transforms_factory.py:9
#       6 import math
#       8 import torch
# ----> 9 from torchvision import transforms
#      11 from timm.data.constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, DEFAULT_CROP_PCT
#      12 from timm.data.auto_augment import rand_augment_transform, augment_and_mix_transform, auto_augment_transform
#
# File ~\anaconda3\Lib\site-packages\torchvision\__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~\anaconda3\Lib\site-packages\torchvision\datasets\__init__.py:1
# ----> 1 from ._optical_flow import FlyingChairs, FlyingThings3D, HD1K, KittiFlow, Sintel
#       2 from ._stereo_matching import (
#       3     CarlaStereo,
#       4     CREStereo,
#    (...)
#      12     SintelStereo,
#      13 )
#      14 from .caltech import Caltech101, Caltech256
#
# File ~\anaconda3\Lib\site-packages\torchvision\datasets\_optical_flow.py:12
#       9 import torch
#      10 from PIL import Image
# ---> 12 from ..io.image import _read_png_16
#      13 from .utils import _read_pfm, verify_str_arg
#      14 from .vision import VisionDataset
#
# File ~\anaconda3\Lib\site-packages\torchvision\io\__init__.py:5
#       1 from typing import Any, Dict, Iterator
#       3 import torch
# ----> 5 from ..utils import _log_api_usage_once
#       7 try:
#       8     from ._load_gpu_decoder import _HAS_GPU_VIDEO_DECODER
#
# File ~\anaconda3\Lib\site-packages\torchvision\utils.py:11
#       9 import numpy as np
#      10 import torch
# ---> 11 from PIL import Image, ImageColor, ImageDraw, ImageFont
#      13 __all__ = [
#      14     "make_grid",
#      15     "save_image",
#    (...)
#      19     "flow_to_image",
#      20 ]
#      23 @torch.no_grad()
#      24 def make_grid(
#      25     tensor: Union[torch.Tensor, List[torch.Tensor]],
#    (...)
#      31     pad_value: float = 0.0,
#      32 ) -> torch.Tensor:
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageDraw.py:40
#      37 from typing import Sequence, cast
#      39 from . import Image, ImageColor
# ---> 40 from ._typing import Coords
#      42 """
#      43 A simple 2D drawing interface for PIL images.
#      44 <p>
#      45 Application code should use the <b>Draw</b> factory, instead of
#      46 directly.
#      47 """
#      50 class ImageDraw:
#
# ImportError: cannot import name 'Coords' from 'PIL._typing' (C:\Users\blind\anaconda3\Lib\site-packages\PIL\_typing.py)

# %%
timm.__version__
